# %%
### Thafat KANEM & Yanis MORIN ###
###   EPSI NANTES 30/01/2026   ###
###      TP Documentation      ###
### -------------------------- ###
###  Entrainement du modèle    ###
###     math score, cross      ###
###  validation, optimisation  ###
###    bayésienne, métrics,    ###
###  visualisation graphique,  ###
###     export du modèle,      ###
###        model cards.        ###

# %%
# Imports
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

from catboost import CatBoostRegressor
from skopt import BayesSearchCV
from skopt.space import Integer, Real

import os
import json
import joblib
import matplotlib.pyplot as plt

# %%
# Data
df = pd.read_csv("data/StudentsPerformance_modified.csv")

# On prédit math score, on exclut les autres scores pour constater un impact hors cadre académique sur les résultats d'un élève
X = df.drop(columns=["reading score", "writing score", "math score", "language mean score"])
y_math = df["math score"]

# CatBoost categorical handling
cat_cols = X.select_dtypes(include="object").columns.tolist()
cat_idx = [X.columns.get_loc(c) for c in cat_cols]

X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(
    X, y_math, test_size=0.2, random_state=42
)

# Cross validation à 5 folds
cv = KFold(n_splits=5, shuffle=True, random_state=42)

base_math = CatBoostRegressor(
    loss_function="RMSE",
    random_seed=42,
    verbose=0
)

search_space = {
    "depth": Integer(3, 10),
    "learning_rate": Real(1e-3, 0.3, prior="log-uniform"),
    "l2_leaf_reg": Real(1.0, 20.0),
    "iterations": Integer(300, 2000),
    "subsample": Real(0.5, 1.0),
    "random_strength": Real(0.0, 2.0),
}

# Optimisation bayésienne des hyperparams
opt_math = BayesSearchCV(
    estimator=base_math,
    search_spaces=search_space,
    n_iter=35,
    cv=cv,
    scoring="r2",
    n_jobs=-1,
    random_state=42,
    verbose=0
)

opt_math.fit(X_train_m, y_train_m, cat_features=cat_idx)

best_model_math = opt_math.best_estimator_
best_params_math = opt_math.best_params_
best_cv_r2_math = float(opt_math.best_score_)

print(" Bayes opt OK (math score). Best CV R2:", best_cv_r2_math)
print("Best params:", best_params_math)

best_model_math.fit(X_train_m, y_train_m, cat_features=cat_idx)

pred_math = best_model_math.predict(X_test_m)

rmse_val = float(np.sqrt(mean_squared_error(y_test_m, pred_math)))

#metrics d'évaluations
math_metrics = {
    "cv_best_r2": best_cv_r2_math,
    "r2_test": float(r2_score(y_test_m, pred_math)),
    "mae_test": float(mean_absolute_error(y_test_m, pred_math)),
    "rmse_test": rmse_val,
    "y_test_mean": float(np.mean(y_test_m)),
}

print("\n math score test metrics:", math_metrics)
# Out:
#  Bayes opt OK (math score). Best CV R2: 0.23062073312941242
# Best params: OrderedDict([('depth', 3), ('iterations', 300), ('l2_leaf_reg', 1.0), ('learning_rate', 0.05542290168219912), ('random_strength', 0.5291589920766805), ('subsample', 0.5)])
#
#  math score test metrics: {'cv_best_r2': 0.23062073312941242, 'r2_test': 0.15067975684941215, 'mae_test': 11.454176959669375, 'rmse_test': 14.37609922948068, 'y_test_mean': 64.46}

# %%
# Création de /artifacts
os.makedirs("artifacts", exist_ok=True)

# ---------- Graphs ----------
plt.scatter(y_test_m, pred_math, alpha=0.6)
plt.xlabel("True score")
plt.ylabel("Predicted score")
plt.title("Math Score — True vs Pred")
mn = min(y_test_m.min(), pred_math.min())
mx = max(y_test_m.max(), pred_math.max())
plt.plot([mn, mx], [mn, mx])
plt.show()

resid = y_test_m - pred_math
plt.figure()
plt.scatter(pred_math, resid, alpha=0.6)
plt.axhline(0)
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.title("Math Score — Residuals vs Pred")
plt.show()

plt.figure()
plt.bar(X.columns, best_model_math.feature_importances_)
plt.xticks(rotation=90)
plt.title("Feature Importance — math score")
plt.show()

# ---------- Export model ----------
joblib.dump(best_model_math, "artifacts/catboost_math_score.joblib")

# ---------- Model card ----------
model_card = f"""# Model Card — CatBoost Math Score Predictor

## Overview
- **Task**: Regression (predict 'math score')
- **Model**: CatBoostRegressor
- **Excluded features**: reading score, writing score, math score{", language mean score" if ("language mean score" in df.columns) else ""}
- **Categorical features**: {cat_cols}

## Data & preprocessing
- Dataset: 'StudentsPerformance_modified.csv'
- Categorical handling: CatBoost native categorical support (no one-hot)

## Training procedure
- Train/Test split: 80/20 (random_state=42)
- Cross-validation: 5-fold KFold (shuffle=True)
- Hyperparameter tuning: Bayesian Optimization (BayesSearchCV, scoring=R²)

## Performance (Test set)
- **Best CV R²**: {math_metrics["cv_best_r2"]:.4f}
- **Test R²**: {math_metrics["r2_test"]:.4f}
- **MAE**: {math_metrics["mae_test"]:.4f}
- **RMSE**: {math_metrics["rmse_test"]:.4f}
- **Mean target**: {math_metrics["y_test_mean"]:.4f}

## Best hyperparameters
```json
{json.dumps(best_params_math, indent=2, ensure_ascii=False)}"""

with open("artifacts/model_card_math_score.md", "w", encoding="utf-8") as f:
    f.write(model_card)
